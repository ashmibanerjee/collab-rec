# %%
import pandas as pd

# %%
df = pd.read_csv('../data/collab-rec-2026/analysis/claude_mami_aggressive_scores.csv')

# %%
df.head()
# Out:
#                query_id                                            filters  \
# 0  c_p_95_pop_high_hard  {"popularity": "high", "month": "December", "b...
# 1  c_p_95_pop_high_hard  {"popularity": "high", "month": "December", "b...
# 2  c_p_95_pop_high_hard  {"popularity": "high", "month": "December", "b...
# 3  c_p_95_pop_high_hard  {"popularity": "high", "month": "December", "b...
# 4  c_p_95_pop_high_hard  {"popularity": "high", "month": "December", "b...
#
#         agent_name  round_nr  \
# 0  personalization         1
# 1   sustainability         1
# 2       popularity         1
# 3        moderator         1
# 4  personalization         2
#
#                                           candidates  success_score  \
# 0  ["Prague", "Vienna", "Budapest", "Krakow", "Be...          0.650
# 1  ["Krakow", "Prague", "Budapest", "Brno", "Cluj...          0.600
# 2  ["Prague", "Budapest", "Krakow", "Vienna", "Br...          0.675
# ...

# %%
df.shape
# Out:
# (27191, 11)

# %%
df.query_id.unique().shape
# Out:
# (680,)

# %%
config_ids = pd.DataFrame(df['query_id'].unique(), columns=['query_id'])
config_ids.to_csv('../data/collab-rec-2026/analysis/multiplicative_scoring_config_ids.csv', index=False)
